# %% [markdown]
# # Quickstart: Compare runs, choose a model, and deploy it to a REST API

# %% [markdown]
# In this quickstart, you will:
# - Run a hyperparameter sweep on a training script.
# - Compare the results of the runs in the MLflow UI.
# - Choose the best run and register it as a model.
# - Deploy the model to a REST API.
# - Build a container image suitable for deployment to a cloud platform.

# %%
import keras
import numpy as np
import pandas as pd 
from hyperopt import STATUS_OK, Trials,fmin,hp,tpe 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import mlflow
from mlflow.models import infer_signature

# %%
# Load The Dataset
data = pd.read_csv("https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
                 sep=";",
)

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# Split the data into training, validation and test sets

train, test = train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train_x = train.drop(['quality'],axis=1).values 
train_y = train[['quality']].values.ravel()

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8], dtype=int64)

# %%
# Validation dataset

test_x = test.drop(['quality'],axis=1).values
test_y = test[['quality']].values.ravel()

# Splitting this train data into train and validation

train_x, valid_x, train_y,valid_y = train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature = infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
# ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    # Defien Model architecture

    mean = np.mean(train_x,axis=0)
    var = np.var(train_x,axis=0)

    model = keras.Sequential([
        keras.Input([train_x.shape[1]]),
        keras.layers.Normalization(mean = mean, variance = var),
        keras.layers.Dense(64,activation='relu'),
        keras.layers.Dense(1)
    ])

    # Compile the Model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate = params["lr"], momentum = params["momentum"]
    ),
    loss = "mean_squared_error",
    metrics = [keras.metrics.RootMeanSquaredError()])

    # Train the ANN Model with lr and momentum params with MLFLOW tracking.
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs = epochs,
                  batch_size=64)
        # Evaluate the model
        eval_result = model.evaluate(valid_x, valid_y, batch_size=64)

        eval_rmse = eval_result[1]
        # Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        # Log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run.
    result = train_model(
        params,
        epochs=3,
        train_x = train_x,
        train_y = train_y,
        valid_x = valid_x,
        valid_y = valid_y,
        test_x = test_x,
        test_y = test_y,
    )
    return result

# %%
space = {
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)
}

# %%
mlflow.set_experiment("/wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameterization
    trials = Trials()
    best=fmin(
        fn=objective,
        space = space,
        algo = tpe.suggest,
        max_evals = 4,
        trials = trials 
    )

    #  Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse",best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature = signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 17s 380ms/step - loss: 37.3437 - root_mean_squared_error: 6.1110
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9038 - root_mean_squared_error: 2.7932
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.5515 - root_mean_squared_error: 2.7323 - val_loss: 1.0052 - val_root_mean_squared_error: 1.0026
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.7456 - root_mean_squared_error: 0.8635
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8276 - root_mean_squared_error: 0.9091 - val_loss: 0.6991 - val_root_mean_squared_error: 0.8361
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.8345 - root_mean_squared_error: 0.9135
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6619 - root_mean_squared_error: 0.8133
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6556 - root_mean_squared_error: 0.8094 - val_loss: 0.5757 - val_root_mean_squared_error: 0.7587
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5699 - root_mean_squared_error: 0.7549
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5744 - root_mean_squared_error: 0.7578
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 16s 367ms/step - loss: 43.1411 - root_mean_squared_error: 6.5682
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38.5954 - root_mean_squared_error: 6.2097
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 38.2363 - root_mean_squared_error: 6.1802 - val_loss: 26.6795 - val_root_mean_squared_error: 5.1652
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 25.8686 - root_mean_squared_error: 5.0861
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.4435 - root_mean_squared_error: 4.8389 - val_loss: 16.2562 - val_root_mean_squared_error: 4.0319
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 15.2578 - root_mean_squared_error: 3.9061
# 39/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.9897 - root_mean_squared_error: 3.7393
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.7746 - root_mean_squared_error: 3.7100 - val_loss: 9.7614 - val_root_mean_squared_error: 3.1243
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 10.6671 - root_mean_squared_error: 3.2661
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8649 - root_mean_squared_error: 3.1405
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 23s 523ms/step - loss: 35.6326 - root_mean_squared_error: 5.9693
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.7122 - root_mean_squared_error: 5.8915
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 34.4029 - root_mean_squared_error: 5.8650 - val_loss: 30.0541 - val_root_mean_squared_error: 5.4822
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 30.2291 - root_mean_squared_error: 5.4981
# 27/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.7039 - root_mean_squared_error: 5.3571
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.1384 - root_mean_squared_error: 5.3039 - val_loss: 24.5004 - val_root_mean_squared_error: 4.9498
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 24.4007 - root_mean_squared_error: 4.9397
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.4341 - root_mean_squared_error: 4.9430
# 23/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.9867 - root_mean_squared_error: 4.8974
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.6071 - root_mean_squared_error: 4.8583
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.3238 - root_mean_squared_error: 4.8288 - val_loss: 19.9097 - val_root_mean_squared_error: 4.4620
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 20.0345 - root_mean_squared_error: 4.4760
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.6027 - root_mean_squared_error: 4.4274
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 40s 909ms/step - loss: 38.4313 - root_mean_squared_error: 6.1993
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.5708 - root_mean_squared_error: 5.9638
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.9053 - root_mean_squared_error: 5.9075
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.3114 - root_mean_squared_error: 5.8567
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 34.2322 - root_mean_squared_error: 5.8499 - val_loss: 28.7643 - val_root_mean_squared_error: 5.3632
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 29.3307 - root_mean_squared_error: 5.4158
# 17/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.5197 - root_mean_squared_error: 5.3400
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.8730 - root_mean_squared_error: 5.2788
# 39/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.5437 - root_mean_squared_error: 5.2473
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.2571 - root_mean_squared_error: 5.2197 - val_loss: 22.8355 - val_root_mean_squared_error: 4.7787
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 12s 273ms/step - loss: 23.9221 - root_mean_squared_error: 4.8910
# 11/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.7320 - root_mean_squared_error: 4.7673
# 21/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.1976 - root_mean_squared_error: 4.7108
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.7676 - root_mean_squared_error: 4.6649
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 21.4944 - root_mean_squared_error: 4.6353 - val_loss: 18.0519 - val_root_mean_squared_error: 4.2487
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 18.3698 - root_mean_squared_error: 4.2860
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9338 - root_mean_squared_error: 4.2348
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 17.9520 - root_mean_squared_error: 4.2369
#
# 100%|██████████| 4/4 [00:58<00:00, 14.54s/trial, best loss: 0.7587348818778992]
# Best parameters: {'lr': 0.015858801190415415, 'momentum': 0.5456873019414639}
# Best eval rmse: 0.7587348818778992

# %%
# Register in the model

mlflow.register_model(model_uri, "wine-quality")
# Out:
# Successfully registered model 'wine-quality'.
# Created version '1' of model 'wine-quality'.
# <ModelVersion: aliases=[], creation_timestamp=1741901135074, current_stage='None', description=None, last_updated_timestamp=1741901135074, name='wine-quality', run_id='a36ed50858794f0c84160df4daa9dced', run_link=None, source='file:///c:/Users/saura/OneDrive/Desktop/mlflow/mlruns/2-DLMLFLOW/mlruns/620891273083526918/a36ed50858794f0c84160df4daa9dced/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=1>
